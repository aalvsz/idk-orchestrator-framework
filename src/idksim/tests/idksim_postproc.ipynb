# %% [markdown]
# ### Resultados de la optimización del travesaño HGP

# %% [markdown]
# #### Correlaciones entre variables

# %%
import optim_post_proc
optim_post_proc.main()
# Out:
# d:\portable_idkSIM\idksimulation\src\idksim\tests\optim_post_proc.py:119: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   analyze_correlations(inputs_df.fillna(0), outputs_df, logger)
# d:\portable_idkSIM\idksimulation\.venv\Lib\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# d:\portable_idkSIM\idksimulation\.venv\Lib\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# 2025-07-02 12:41:20,138 -
# ✅ Correlaciones con Peso:
# 2025-07-02 12:41:20,140 - t_bottom       0.904262
# t2_trans       0.881670
# t_top          0.826324
# d_t_trans     -0.809883
# N_trans        0.781333
# ang_Z         -0.765346
# ...

# %% [markdown]
# #### Frente de Pareto

# %%
import manual_pareto
manual_pareto.main()

# %% [markdown]
# #### Curvas de rectitud

# %% [markdown]
# Se han elegido arbitrariamente 5 soluciones del frente de pareto en diferentes puntos, y se han comparado los resultados obtenidos en cuanto a rectitud con los resultados nominales.

# %%
import tcp_graphs
tcp_graphs.main(1)
# Out:
# ####################
# ✅ Gráfico guardado en D:\idk_framework\idksimulation\results\__ROM_travesano_peso_en_elastica\tcp_graphs\dic1_subplots.png

# %%
import tcp_graphs
tcp_graphs.main(2)
# Out:
# ####################
# ✅ Gráfico guardado en D:\idk_framework\idksimulation\results\__ROM_travesano_peso_en_elastica\tcp_graphs\dic2_subplots.png

# %%
import tcp_graphs
tcp_graphs.main(3)
# Out:
# ####################
# ✅ Gráfico guardado en D:\idk_framework\idksimulation\results\__ROM_travesano_peso_en_elastica\tcp_graphs\dic3_subplots.png

# %%
import tcp_graphs
tcp_graphs.main(4)
# Out:
# ####################
# ✅ Gráfico guardado en D:\idk_framework\idksimulation\results\__ROM_travesano_peso_en_elastica\tcp_graphs\dic4_subplots.png

# %%
import tcp_graphs
tcp_graphs.main(5)
# Out:
# ####################
# ✅ Gráfico guardado en D:\idk_framework\idksimulation\results\__ROM_travesano_peso_en_elastica\tcp_graphs\dic5_subplots.png

# %% [markdown]
# #### Histogramas
